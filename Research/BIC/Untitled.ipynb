# %% [markdown]
# # BIC for Manual Program

# %% [markdown]
# ### random transition probs + random emission probs

# %% [markdown]
# ![MRR1.png](attachment:MRR1.png)
# ![MRR2.png](attachment:MRR2.png)

# %% [markdown]
# ### uniform transition probs + random emission probs

# %% [markdown]
# ![MUR1.png](attachment:MUR1.png)![MUR2.png](attachment:MUR2.png)

# %% [markdown]
# # BIC for Manual + Supervisory Program

# %% [markdown]
# ### random transition probs + random emission probs

# %%
import cPickle as pickle
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f7f8faa08777> in <module>()
#       1
# ----> 2 import cPickle as pickle
#
# ModuleNotFoundError: No module named 'cPickle'
